# %%
import os
import matplotlib.pyplot as plt


# %matplotlib inline

data = []
for filename in os.listdir('experiment1/cumu_rewards/'):
    with open('experiment1/cumu_rewards/' + filename, 'r') as f:
        data.append(f.readlines())
        
for i in range(len(data)):
    data[i] = [d.rstrip() for d in data[i]]
    data[i] = [float(d) for d in data[i]]

fig, ax = plt.subplots()
for i in range(len(data)):
    ax.plot([j for j in range(len(data[i]))], data[i])

plt.xlabel('Episodes')
plt.ylabel('Cumulative Reward')
plt.show()

# %%
for filename in os.listdir('experiment1/cumu_rewards/'):
    print(filename)
# Out:
# cumulative_rewards2019-11-20 00:04:30.332093
# cumulative_rewards2019-11-20 00:04:21.236923
# cumulative_rewards2019-11-20 00:04:15.202258
# cumulative_rewards2019-11-20 00:04:30.321168
# cumulative_rewards2019-11-20 00:04:24.505007
# cumulative_rewards2019-11-20 00:04:27.513433
# cumulative_rewards2019-11-20 00:04:18.130770
# cumulative_rewards2019-11-20 00:04:13.597349
# cumulative_rewards2019-11-20 00:04:18.237936
# cumulative_rewards2019-11-20 00:04:24.528173
